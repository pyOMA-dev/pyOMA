# %% [markdown]
# # pyOMA – Multi-Setup OMA with PoGER merging
#
# Interactive Jupyter companion to `scripts/multi_setup_analysis_poger.py`.
#
# PoGER (Post Global Estimation Re-scaling) merges setups **before** modal
# identification: correlation functions from all setups are stacked into a
# joint Hankel matrix, and a single SSI run yields global frequencies,
# damping ratios, and re-scaled mode shapes directly — no separate merge
# step is required.  Compare with `multi_setup_analysis.ipynb` (PoSER),
# where SSI is run per setup and modal parameters are merged afterwards.
#
# | Step | Cell | Description |
# |------|------|-------------|
# | 1 | Geometry | Load nodes, lines, parent–child assignments |
# | 2 | Per-setup loop | Pre-process signals and add each setup to the PoGER object |
# | 3 | Joint ID | Pair channels, build joint Hankel matrix, estimate modal parameters |
# | 4a | StabilGUIWeb | Interactive stabilisation diagram — select poles manually |
# | 4b | Auto-select | Headless alternative when interactive GUI is not needed |
# | 5 | Results | Print identified frequencies and damping ratios |
# | 6 | PlotMSHWeb | Animate mode shapes interactively |
#
# > **Requirements:** `pip install "pyOMA[jupyter]"`
# >
# > Run cells top-to-bottom with **Shift+Enter**.  After selecting poles in
# > the stabilisation diagram (Step 4a), continue from Step 5 onwards.

# %% [markdown]
# ## 0  Imports and display backend

# %%
from pathlib import Path
import numpy as np
import ipympl  # noqa: F401 – activates the widget backend
# %matplotlib widget
import matplotlib.pyplot as plt

from IPython.display import display

from pyOMA.core import (
    GeometryProcessor,
    SignalPlot,
    PreProcessSignals,
    PogerSSICovRef,
    StabilCluster,
    StabilPlot,
    resolve_mode_shape_backend,
)
from pyOMA.core.Helpers import ConfigFile
from pyOMA.GUI.JupyterGUI import StabilGUIWeb, PlotMSHWeb

# Pick the 3-D mode-shape backend once, honouring PYOMA_MSH_BACKEND /
# pyOMA.core.MSH_BACKEND (default: the pyvista notebook backend when the
# pyOMA[pyvista] extra is installed, else matplotlib).
MSHPlot = resolve_mode_shape_backend('notebook')

print('pyOMA imported successfully')
print(f'Mode-shape backend: {MSHPlot.__name__}')
# Out:
# pyOMA imported successfully
# Mode-shape backend: ModeShapePlotPVJupyter

# %% [markdown]
# ## 1  Configuration
#
# Adjust the paths and parameters below to match your project.

# %%
import pyOMA

# Root of the repository — works whether pyOMA is installed or run in-place
REPO_ROOT    = Path(pyOMA.__file__).parent.parent
EXAMPLE_DATA = REPO_ROOT / 'tests' / 'files'

# PoGER uses SSI-cov/ref; the config provides num_block_columns and max_model_order
CONF_FILE = EXAMPLE_DATA / 'ssi_config.txt'

# Stabilisation thresholds
STABIL_KWARGS = dict(
    d_range=(0, 0.5),
    df_max=0.01,
    dd_max=0.05,
    dmac_max=0.05,
)

SKIP_EXISTING = False  # load saved intermediate results when True
SAVE_RESULTS  = False  # persist intermediate results to disk when True

PreProcessSignals.load_measurement_file = np.load

assert EXAMPLE_DATA.exists(), f'Example data not found at {EXAMPLE_DATA}'
print(f'Data root : {EXAMPLE_DATA}')
print(f'Config    : {CONF_FILE.name}')
# Out:
# Data root : /home/womo1998/dev/pyOMA/tests/files
# Config    : ssi_config.txt

# %% [markdown]
# ## 2  Structural geometry

# %%
geometry_data = GeometryProcessor.load_geometry(
    nodes_file=EXAMPLE_DATA / 'grid.txt',
    lines_file=EXAMPLE_DATA / 'lines.txt',
    parent_childs_file=EXAMPLE_DATA / 'parent_child_assignments.txt',
)
print(f'{len(geometry_data.nodes)} nodes, {len(geometry_data.lines)} lines loaded')
# Out:
# 24 nodes, 40 lines loaded

# %% [markdown]
# ## 3  Per-setup loop: signal pre-processing
#
# Each setup is pre-processed independently (decimation, correlation functions)
# and then added to the shared `PogerSSICovRef` object.  The actual modal
# identification happens in the next cell using the jointly stacked data.

# %%
setup_dirs = sorted(
    EXAMPLE_DATA.glob('measurement_*'),
    key=lambda p: int(p.name.split('_')[1]),
)

poger = PogerSSICovRef()

for setup_dir in setup_dirs:
    meas_name = setup_dir.name
    print(f'\n── {meas_name} ──')

    _prep_state = setup_dir / 'prep_data.npz'
    if _prep_state.exists() and SKIP_EXISTING:
        prep_signals = PreProcessSignals.load_state(_prep_state)
    else:
        prep_signals = PreProcessSignals.init_from_config(
            conf_file=setup_dir / 'setup_info.txt',
            meas_file=setup_dir / f'{meas_name}.npy',
            chan_dofs_file=setup_dir / 'channel_dofs.txt',
        )
        prep_signals.decimate_signals(3)
        prep_signals.decimate_signals(3)
        prep_signals.correlation(m_lags=401)
        prep_signals.psd()
        if SAVE_RESULTS:
            prep_signals.save_state(_prep_state)

    poger.add_setup(prep_signals)

print(f'\n{len(poger.setups)} setup(s) added.')
# Out:
# ── measurement_1 ──
# INFO:pyOMA.core.PreProcessingTools:Now removing Channel ref_z (no. 5)!
# INFO:pyOMA.core.PreProcessingTools:Decimating signals by factor 3 to a sampling rate of 85.33333333333333 Hz
# INFO:pyOMA.core.PreProcessingTools:Filtering signals in the band: None .. 34.13333333333333 with a 8 order cheby1 filter.
# INFO:pyOMA.core.PreProcessingTools:Decimating signals by factor 3 to a sampling rate of 28.444444444444443 Hz
# INFO:pyOMA.core.PreProcessingTools:Filtering signals in the band: None .. 11.377777777777776 with a 8 order cheby1 filter.
# INFO:pyOMA.core.PreProcessingTools:Estimating Correlation Functions (BT) with m_lags=401 and n_segments=1...
# ....................................................................................................
# INFO:pyOMA.core.PreProcessingTools:Estimating Power Spectral Density by Blackman-Tukey's method...
# ....................................................................................................
# INFO:pyOMA.core.SSICovRef:Added setup "measurement_1" with 5 channels
#
# ── measurement_2 ──
# INFO:pyOMA.core.PreProcessingTools:Now removing Channel ref_z (no. 5)!
# INFO:pyOMA.core.PreProcessingTools:Decimating signals by factor 3 to a sampling rate of 85.33333333333333 Hz
# INFO:pyOMA.core.PreProcessingTools:Filtering signals in the band: None .. 34.13333333333333 with a 8 order cheby1 filter.
# INFO:pyOMA.core.PreProcessingTools:Decimating signals by factor 3 to a sampling rate of 28.444444444444443 Hz
# INFO:pyOMA.core.PreProcessingTools:Filtering signals in the band: None .. 11.377777777777776 with a 8 order cheby1 filter.
# INFO:pyOMA.core.PreProcessingTools:Estimating Correlation Functions (BT) with m_lags=401 and n_segments=1...
# ....................................................................................................
# INFO:pyOMA.core.PreProcessingTools:Estimating Power Spectral Density by Blackman-Tukey's method...
# ....................................................................................................
# INFO:pyOMA.core.SSICovRef:Added setup "measurement_2" with 5 channels
#
# ── measurement_3 ──
# INFO:pyOMA.core.PreProcessingTools:Now removing Channel ref_z (no. 5)!
# INFO:pyOMA.core.PreProcessingTools:Decimating signals by factor 3 to a sampling rate of 85.33333333333333 Hz
# INFO:pyOMA.core.PreProcessingTools:Filtering signals in the band: None .. 34.13333333333333 with a 8 order cheby1 filter.
# INFO:pyOMA.core.PreProcessingTools:Decimating signals by factor 3 to a sampling rate of 28.444444444444443 Hz
# INFO:pyOMA.core.PreProcessingTools:Filtering signals in the band: None .. 11.377777777777776 with a 8 order cheby1 filter.
# INFO:pyOMA.core.PreProcessingTools:Estimating Correlation Functions (BT) with m_lags=401 and n_segments=1...
# ....................................................................................................
# INFO:pyOMA.core.PreProcessingTools:Estimating Power Spectral Density by Blackman-Tukey's method...
# ....................................................................................................
# INFO:pyOMA.core.SSICovRef:Added setup "measurement_3" with 5 channels
#
# ── measurement_4 ──
# INFO:pyOMA.core.PreProcessingTools:Now removing Channel ref_z (no. 5)!
# INFO:pyOMA.core.PreProcessingTools:Decimating signals by factor 3 to a sampling rate of 85.33333333333333 Hz
# INFO:pyOMA.core.PreProcessingTools:Filtering signals in the band: None .. 34.13333333333333 with a 8 order cheby1 filter.
# INFO:pyOMA.core.PreProcessingTools:Decimating signals by factor 3 to a sampling rate of 28.444444444444443 Hz
# INFO:pyOMA.core.PreProcessingTools:Filtering signals in the band: None .. 11.377777777777776 with a 8 order cheby1 filter.
# INFO:pyOMA.core.PreProcessingTools:Estimating Correlation Functions (BT) with m_lags=401 and n_segments=1...
# ....................................................................................................
# INFO:pyOMA.core.PreProcessingTools:Estimating Power Spectral Density by Blackman-Tukey's method...
# ....................................................................................................
# INFO:pyOMA.core.SSICovRef:Added setup "measurement_4" with 5 channels
#
# ── measurement_5 ──
# INFO:pyOMA.core.PreProcessingTools:Now removing Channel ref_z (no. 5)!
# INFO:pyOMA.core.PreProcessingTools:Decimating signals by factor 3 to a sampling rate of 85.33333333333333 Hz
# INFO:pyOMA.core.PreProcessingTools:Filtering signals in the band: None .. 34.13333333333333 with a 8 order cheby1 filter.
# INFO:pyOMA.core.PreProcessingTools:Decimating signals by factor 3 to a sampling rate of 28.444444444444443 Hz
# INFO:pyOMA.core.PreProcessingTools:Filtering signals in the band: None .. 11.377777777777776 with a 8 order cheby1 filter.
# INFO:pyOMA.core.PreProcessingTools:Estimating Correlation Functions (BT) with m_lags=401 and n_segments=1...
# ....................................................................................................
# INFO:pyOMA.core.PreProcessingTools:Estimating Power Spectral Density by Blackman-Tukey's method...
# ....................................................................................................
# INFO:pyOMA.core.SSICovRef:Added setup "measurement_5" with 5 channels
#
# ── measurement_6 ──
# INFO:pyOMA.core.PreProcessingTools:Now removing Channel ref_z (no. 5)!
# INFO:pyOMA.core.PreProcessingTools:Decimating signals by factor 3 to a sampling rate of 85.33333333333333 Hz
# INFO:pyOMA.core.PreProcessingTools:Filtering signals in the band: None .. 34.13333333333333 with a 8 order cheby1 filter.
# INFO:pyOMA.core.PreProcessingTools:Decimating signals by factor 3 to a sampling rate of 28.444444444444443 Hz
# INFO:pyOMA.core.PreProcessingTools:Filtering signals in the band: None .. 11.377777777777776 with a 8 order cheby1 filter.
# INFO:pyOMA.core.PreProcessingTools:Estimating Correlation Functions (BT) with m_lags=401 and n_segments=1...
# ....................................................................................................
# INFO:pyOMA.core.PreProcessingTools:Estimating Power Spectral Density by Blackman-Tukey's method...
# ....................................................................................................
# INFO:pyOMA.core.SSICovRef:Added setup "measurement_6" with 5 channels
#
# ── measurement_7 ──
# INFO:pyOMA.core.PreProcessingTools:Now removing Channel ref_z (no. 5)!
# INFO:pyOMA.core.PreProcessingTools:Decimating signals by factor 3 to a sampling rate of 85.33333333333333 Hz
# INFO:pyOMA.core.PreProcessingTools:Filtering signals in the band: None .. 34.13333333333333 with a 8 order cheby1 filter.
# INFO:pyOMA.core.PreProcessingTools:Decimating signals by factor 3 to a sampling rate of 28.444444444444443 Hz
# INFO:pyOMA.core.PreProcessingTools:Filtering signals in the band: None .. 11.377777777777776 with a 8 order cheby1 filter.
# INFO:pyOMA.core.PreProcessingTools:Estimating Correlation Functions (BT) with m_lags=401 and n_segments=1...
# ....................................................................................................
# INFO:pyOMA.core.PreProcessingTools:Estimating Power Spectral Density by Blackman-Tukey's method...
# ....................................................................................................
# INFO:pyOMA.core.SSICovRef:Added setup "measurement_7" with 5 channels
#
# ── measurement_8 ──
# INFO:pyOMA.core.PreProcessingTools:Now removing Channel ref_z (no. 5)!
# INFO:pyOMA.core.PreProcessingTools:Decimating signals by factor 3 to a sampling rate of 85.33333333333333 Hz
# INFO:pyOMA.core.PreProcessingTools:Filtering signals in the band: None .. 34.13333333333333 with a 8 order cheby1 filter.
# INFO:pyOMA.core.PreProcessingTools:Decimating signals by factor 3 to a sampling rate of 28.444444444444443 Hz
# INFO:pyOMA.core.PreProcessingTools:Filtering signals in the band: None .. 11.377777777777776 with a 8 order cheby1 filter.
# INFO:pyOMA.core.PreProcessingTools:Estimating Correlation Functions (BT) with m_lags=401 and n_segments=1...
# ....................................................................................................
# INFO:pyOMA.core.PreProcessingTools:Estimating Power Spectral Density by Blackman-Tukey's method...
# ....................................................................................................
# INFO:pyOMA.core.SSICovRef:Added setup "measurement_8" with 5 channels
#
# ── measurement_9 ──
# INFO:pyOMA.core.PreProcessingTools:Now removing Channel ref_z (no. 5)!
# INFO:pyOMA.core.PreProcessingTools:Decimating signals by factor 3 to a sampling rate of 85.33333333333333 Hz
# INFO:pyOMA.core.PreProcessingTools:Filtering signals in the band: None .. 34.13333333333333 with a 8 order cheby1 filter.
# INFO:pyOMA.core.PreProcessingTools:Decimating signals by factor 3 to a sampling rate of 28.444444444444443 Hz
# INFO:pyOMA.core.PreProcessingTools:Filtering signals in the band: None .. 11.377777777777776 with a 8 order cheby1 filter.
# INFO:pyOMA.core.PreProcessingTools:Estimating Correlation Functions (BT) with m_lags=401 and n_segments=1...
# ....................................................................................................
# INFO:pyOMA.core.PreProcessingTools:Estimating Power Spectral Density by Blackman-Tukey's method...
# ....................................................................................................
# INFO:pyOMA.core.SSICovRef:Added setup "measurement_9" with 5 channels
#
# ── measurement_10 ──
# INFO:pyOMA.core.PreProcessingTools:Now removing Channel ref_z (no. 5)!
# INFO:pyOMA.core.PreProcessingTools:Decimating signals by factor 3 to a sampling rate of 85.33333333333333 Hz
# INFO:pyOMA.core.PreProcessingTools:Filtering signals in the band: None .. 34.13333333333333 with a 8 order cheby1 filter.
# INFO:pyOMA.core.PreProcessingTools:Decimating signals by factor 3 to a sampling rate of 28.444444444444443 Hz
# INFO:pyOMA.core.PreProcessingTools:Filtering signals in the band: None .. 11.377777777777776 with a 8 order cheby1 filter.
# INFO:pyOMA.core.PreProcessingTools:Estimating Correlation Functions (BT) with m_lags=401 and n_segments=1...
# ....................................................................................................
# INFO:pyOMA.core.PreProcessingTools:Estimating Power Spectral Density by Blackman-Tukey's method...
# ....................................................................................................
# INFO:pyOMA.core.SSICovRef:Added setup "measurement_10" with 5 channels
#
# ── measurement_11 ──
# INFO:pyOMA.core.PreProcessingTools:Now removing Channel ref_z (no. 5)!
# INFO:pyOMA.core.PreProcessingTools:Decimating signals by factor 3 to a sampling rate of 85.33333333333333 Hz
# INFO:pyOMA.core.PreProcessingTools:Filtering signals in the band: None .. 34.13333333333333 with a 8 order cheby1 filter.
# INFO:pyOMA.core.PreProcessingTools:Decimating signals by factor 3 to a sampling rate of 28.444444444444443 Hz
# INFO:pyOMA.core.PreProcessingTools:Filtering signals in the band: None .. 11.377777777777776 with a 8 order cheby1 filter.
# INFO:pyOMA.core.PreProcessingTools:Estimating Correlation Functions (BT) with m_lags=401 and n_segments=1...
# ....................................................................................................
# INFO:pyOMA.core.PreProcessingTools:Estimating Power Spectral Density by Blackman-Tukey's method...
# ....................................................................................................
# INFO:pyOMA.core.SSICovRef:Added setup "measurement_11" with 5 channels
#
# ── measurement_12 ──
# INFO:pyOMA.core.PreProcessingTools:Now removing Channel ref_z (no. 5)!
# INFO:pyOMA.core.PreProcessingTools:Decimating signals by factor 3 to a sampling rate of 85.33333333333333 Hz
# INFO:pyOMA.core.PreProcessingTools:Filtering signals in the band: None .. 34.13333333333333 with a 8 order cheby1 filter.
# INFO:pyOMA.core.PreProcessingTools:Decimating signals by factor 3 to a sampling rate of 28.444444444444443 Hz
# INFO:pyOMA.core.PreProcessingTools:Filtering signals in the band: None .. 11.377777777777776 with a 8 order cheby1 filter.
# INFO:pyOMA.core.PreProcessingTools:Estimating Correlation Functions (BT) with m_lags=401 and n_segments=1...
# ....................................................................................................
# INFO:pyOMA.core.PreProcessingTools:Estimating Power Spectral Density by Blackman-Tukey's method...
# ....................................................................................................
# INFO:pyOMA.core.SSICovRef:Added setup "measurement_12" with 5 channels
#
# ── measurement_13 ──
# INFO:pyOMA.core.PreProcessingTools:Now removing Channel ref_z (no. 5)!
# INFO:pyOMA.core.PreProcessingTools:Decimating signals by factor 3 to a sampling rate of 85.33333333333333 Hz
# INFO:pyOMA.core.PreProcessingTools:Filtering signals in the band: None .. 34.13333333333333 with a 8 order cheby1 filter.
# INFO:pyOMA.core.PreProcessingTools:Decimating signals by factor 3 to a sampling rate of 28.444444444444443 Hz
# INFO:pyOMA.core.PreProcessingTools:Filtering signals in the band: None .. 11.377777777777776 with a 8 order cheby1 filter.
# INFO:pyOMA.core.PreProcessingTools:Estimating Correlation Functions (BT) with m_lags=401 and n_segments=1...
# ....................................................................................................
# INFO:pyOMA.core.PreProcessingTools:Estimating Power Spectral Density by Blackman-Tukey's method...
# ....................................................................................................
# INFO:pyOMA.core.SSICovRef:Added setup "measurement_13" with 5 channels
#
# ── measurement_14 ──
# INFO:pyOMA.core.PreProcessingTools:Now removing Channel ref_z (no. 5)!
# INFO:pyOMA.core.PreProcessingTools:Decimating signals by factor 3 to a sampling rate of 85.33333333333333 Hz
# INFO:pyOMA.core.PreProcessingTools:Filtering signals in the band: None .. 34.13333333333333 with a 8 order cheby1 filter.
# INFO:pyOMA.core.PreProcessingTools:Decimating signals by factor 3 to a sampling rate of 28.444444444444443 Hz
# INFO:pyOMA.core.PreProcessingTools:Filtering signals in the band: None .. 11.377777777777776 with a 8 order cheby1 filter.
# INFO:pyOMA.core.PreProcessingTools:Estimating Correlation Functions (BT) with m_lags=401 and n_segments=1...
# ....................................................................................................
# INFO:pyOMA.core.PreProcessingTools:Estimating Power Spectral Density by Blackman-Tukey's method...
# ....................................................................................................
# INFO:pyOMA.core.SSICovRef:Added setup "measurement_14" with 5 channels
#
# ── measurement_15 ──
# INFO:pyOMA.core.PreProcessingTools:Now removing Channel ref_z (no. 5)!
# INFO:pyOMA.core.PreProcessingTools:Decimating signals by factor 3 to a sampling rate of 85.33333333333333 Hz
# INFO:pyOMA.core.PreProcessingTools:Filtering signals in the band: None .. 34.13333333333333 with a 8 order cheby1 filter.
# INFO:pyOMA.core.PreProcessingTools:Decimating signals by factor 3 to a sampling rate of 28.444444444444443 Hz
# INFO:pyOMA.core.PreProcessingTools:Filtering signals in the band: None .. 11.377777777777776 with a 8 order cheby1 filter.
# INFO:pyOMA.core.PreProcessingTools:Estimating Correlation Functions (BT) with m_lags=401 and n_segments=1...
# ....................................................................................................
# INFO:pyOMA.core.PreProcessingTools:Estimating Power Spectral Density by Blackman-Tukey's method...
# ....................................................................................................
# INFO:pyOMA.core.SSICovRef:Added setup "measurement_15" with 5 channels
#
# 15 setup(s) added.

# %% [markdown]
# ### Geometry with sensor positions
#
# The plot below shows the structural nodes and lines together with channel-DOF arrows for the *last* pre-processed setup. Arrows indicate each sensor's measurement direction. Both the matplotlib and the pyvista notebook backend draw the arrows and node labels.

# %%
setup_dir = setup_dirs[7]
meas_name = setup_dir.name
tmp_prep_signals = PreProcessSignals.init_from_config(
    conf_file=setup_dir / 'setup_info.txt',
    meas_file=setup_dir / f'{meas_name}.npy',
    chan_dofs_file=setup_dir / 'channel_dofs.txt',)

geo_plot = MSHPlot(geometry_data=geometry_data, prep_signals=tmp_prep_signals)

if hasattr(geo_plot, 'plotter'):
    # pyvista notebook backend: interactive view with nodes, lines and
    # channel-DOF direction arrows/labels.
    geo_plot.refresh_chan_dofs(True)
    geo_plot.refresh_parent_childs(False)
    display(geo_plot.widget)
else:
    geo_plot.reset_view()
    geo_plot.draw_nodes()
    geo_plot.draw_lines()
    geo_plot.draw_chan_dofs()
    geo_plot.refresh_parent_childs(False)
    geo_plot.subplot.view_init(elev=20, azim=110)
    display(geo_plot.fig)
# Out:
# INFO:pyOMA.core.PreProcessingTools:Now removing Channel ref_z (no. 5)!
# INFO:pyOMA.core.ModeShapeBase:Identified merging routine: None will not use argument prep_signals.
# /home/womo1998/dev/pyOMA/pyOMA/core/PlotMSHpv.py:1509: UserWarning: Suppress rendering on the plotter is changed to False
#   self._viewer = get_viewer(self.plotter)
# VBox(children=(Widget(value='<iframe src="http://localhost:42523/index.html?ui=P_0x7d304beb8ec0_0&reconnect=au…

# %% [markdown]
# ### Signal inspection
#
# Inspect the time-series and power spectral densities for the last pre-processed setup before running identification.

# %%
sig_plot = SignalPlot(prep_signals)
sig_plot.plot_signals(per_channel_axes=True, psd_scale='db')
plt.suptitle(f'Signals — {prep_signals.setup_name}', fontsize=12)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## 4  Joint PoGER identification
#
# Channels common to all setups are paired as SSI reference channels.
# The correlation matrices are stacked into a joint block-Hankel matrix
# and decomposed via SVD.  A single SSI run extracts global modal parameters
# and re-scales partial mode shapes to the reference of the first setup.

# %%
poger.pair_channels()

cfg = ConfigFile(CONF_FILE)
num_block_columns = cfg.int('Number of Block-Columns')
max_model_order   = cfg.int('Maximum Model Order')

_poger_state = EXAMPLE_DATA / 'poger_modal_data.npz'
if _poger_state.exists() and SKIP_EXISTING:
    poger = PogerSSICovRef.load_state(_poger_state)
else:
    poger.build_merged_subspace_matrix(num_block_columns)
    poger.compute_modal_params(max_model_order)
    if SAVE_RESULTS:
        poger.save_state(_poger_state)

stabil_calc = StabilCluster(poger)
stabil_calc.calculate_stabilization_masks(**STABIL_KWARGS)
stabil_plot = StabilPlot(stabil_calc)

print('Joint identification complete.')
print(f'  Block columns : {num_block_columns}')
print(f'  Max order     : {max_model_order}')
# Out:
# INFO:pyOMA.core.SSICovRef:Pairing channels and dofs...
# INFO:pyOMA.core.SSICovRef:Assembling subspace matrix using pre-computed correlation functions from 15 setups with 200 block-columns and 201 block rows
# INFO:pyOMA.core.SSICovRef:Computing modal parameters...
# ....................................................................................................
# INFO:pyOMA.core.StabilDiagram:Checking stabilisation criteria...
# ....................................................................................................
# Joint identification complete.
#   Block columns : 200
#   Max order     : 40

# %% [markdown]
# ## 5a  Interactive pole selection
#
# Switch the **Cursor** radio button to *Stable*, hover over a stable pole
# cluster and **click** to select it.  Click again to deselect.  Adjust the
# soft/hard criteria sliders to refine what counts as “stable” before selecting.
#
# Once satisfied, continue to **Step 5 (Results)**.
#
# > **Tip:** For fully automatic selection, skip this cell and run **Step 4b** instead.

# %%
stabil_widget, cursor = StabilGUIWeb(stabil_plot)
display(stabil_widget)
# Out:
# VBox(children=(VBox(children=(Canvas(footer_visible=False, header_visible=False, resizable=False, toolbar=Tool…

# %%
if not stabil_calc.select_modes:
    stabil_calc.automatic_selection()
print(f'{len(stabil_calc.select_modes)} mode(s) selected')

# %% [markdown]
# ## 6  Results

# %%
selected_freqs = [poger.modal_frequencies[i] for i in stabil_calc.select_modes]
selected_damps = [poger.modal_damping[i]      for i in stabil_calc.select_modes]
n_modes  = len(selected_freqs)
n_setups = len(poger.setups)

print(f'\nPoGER results  ({n_setups} setup(s), {n_modes} mode(s))')
print('\u2500' * 46)
print(f'  {"#":>3}  {"Freq [Hz]":>10}  {"Damp [%]":>10}')
print('\u2500' * 46)
for i, (f, d) in enumerate(zip(selected_freqs, selected_damps), 1):
    print(f'  {i:>3}  {f:>10.3f}  {d:>10.3f}')
print('\u2500' * 46)
# Out:
# PoGER results  (15 setup(s), 8 mode(s))
# ──────────────────────────────────────────────
#     #   Freq [Hz]    Damp [%]
# ──────────────────────────────────────────────
#     1       1.229       0.230
#     2       1.436       0.146
#     3       2.100       0.129
#     4       4.017       0.162
#     5       4.769       0.185
#     6       6.683       0.172
#     7       7.614       0.193
#     8       9.664       0.194
# ──────────────────────────────────────────────

# %% [markdown]
# ## 7  Mode shape visualisation
#
# Displays the identified mode shapes on the 3-D geometry through `MSHPlot`, so
# it uses whichever backend `PYOMA_MSH_BACKEND` selects.  Use the **Mode**
# dropdown to switch between modes and the **play** button to animate.

# %%
msp = MSHPlot(
    geometry_data=geometry_data,
    stabil_calc=stabil_calc,
    modal_data=poger,
    prep_signals=poger.prep_signals,
    amplitude=20,
)
msh_widget = PlotMSHWeb(msp)
display(msh_widget)
# Out:
# INFO:pyOMA.core.ModeShapeBase:Identified merging routine: PoGER will not use argument prep_signals.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 8
#       4     modal_data=poger,
#       5     prep_signals=poger.prep_signals,
#       6     amplitude=20,
#       7 )
# ----> 8 msh_widget = PlotMSHWeb(msp)
#       9 display(msh_widget)
#
# File ~/dev/pyOMA/pyOMA/GUI/JupyterGUI.py:843, in PlotMSHWeb(msp)
#     817 """Display an interactive 3-D mode-shape viewer in Jupyter.
#     818
#     819 Dispatches on the mode-shape backend of *msp*, returning an equivalent
#    (...)    840     Assembled widget ready for ``display()``.
#     841 """
#     842 if _is_pyvista_backend(msp):
# --> 843     return _plotmshweb_pyvista(msp)
#     845 # setup Figure for display with ipympl
#     846 fig = msp.fig
#
# File ~/dev/pyOMA/pyOMA/GUI/JupyterGUI.py:776, in _plotmshweb_pyvista(msp)
#     773     cb.observe(lambda d, m=method: m(d['new']), names='value', type='change')
#     775 # View controls: angle sliders + named-view buttons + reset.
# --> 776 viewbox, (fse, fsa, fsr), view_buttons, res_btn = _msh_build_viewbox(msp)
#     778 def _apply_angles(_change=None):
#     779     msp.change_viewport((fse.value, fsa.value, fsr.value))
#
# File ~/dev/pyOMA/pyOMA/GUI/JupyterGUI.py:595, in _msh_build_viewbox(msp)
#     588 """Build the View controls VBox for PlotMSHWeb.
#     589
#     590 Reads the initial angles through the backend-neutral ``get_view_angles()``
#     591 (matplotlib returns its Axes3D elev/azim/roll; the pyvista backends derive
#     592 them from the camera), so this serves either backend.
#     593 """
#     594 lb = ipywidgets.Label(value='View:')
# --> 595 elev, azim, roll = msp.get_view_angles()
#     596 fse = ipywidgets.FloatSlider(value=elev, min=-180, max=180, step=1,
#     597                              description='Elevation', continuous_update=True)
#     598 fsa = ipywidgets.FloatSlider(value=azim, min=-180, max=180, step=1,
#     599                              description='Azimuth', continuous_update=True)
#
# TypeError: cannot unpack non-iterable NoneType object
